# %% [markdown]
# # Joining Weather Events & Motor Vehicle Claims

# %% [markdown]
# ### Intro

# %% [markdown]
# ##### Joining ACC motor claims dataframes to the weather events NZ dataframe and evaluating the relationships.

# %% [markdown]
# ### Libraries and importng csvs

# %%
library(tidyverse)

# %%
# install.packages("magrittr")
# install.packages("purrr")
library(dplyr)
library(magrittr) # better handling of pipes
library(purrr)

# %%
age <- "age.csv" %>%
              read_csv() 
ethnicity <- "ethnicity.csv" %>%
              read_csv() 
gender <- "gender.csv" %>%
              read_csv()  
month <- "month.csv" %>%
              read_csv() 
region <- "region.csv" %>%
              read_csv() 
road <- "road.csv" %>%
              read_csv() 
weather <- "weather.csv" %>%
              read_csv()
# Out:
# Parsed with column specification:
# cols(
#   age = col_character(),
#   year = col_double(),
#   active_claims = col_double(),
#   New_claims = col_double()
# )
#
# Parsed with column specification:
# cols(
#   ethnicity = col_character(),
#   year = col_double(),
#   active_claims = col_double(),
#   New_claims = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gender = col_character(),
#   year = col_double(),
#   active_claims = col_double(),
#   New_claims = col_double()
# )
#
# Parsed with column specification:
# cols(
#   month = col_character(),
#   year = col_double(),
#   active_claims = col_double(),
#   New_claims = col_double()
# )
#
# Parsed with column specification:
# cols(
#   region = col_character(),
#   year = col_double(),
#   active_claims = col_double(),
#   New_claims = col_double()
# )
#
# Parsed with column specification:
# cols(
#   road_factor = col_character(),
#   year = col_double(),
#   active_claims = col_double(),
#   New_claims = col_double()
# )
#
# Parsed with column specification:
# cols(
#   Year = col_double(),
#   Month = col_character(),
#   `Affected Area` = col_character(),
#   `Weather Event` = col_character(),
#   Description = col_character()
# )

# %% [markdown]
# ## Research Question 1 - New ACC claims and Weather events - is there a relationship ?

# %%
#need to change column name of Weather Event and Affected Area to one word 

weather_a <- weather %>% rename (weather_event = "Weather Event") %>%
    rename (affected_area = "Affected Area") %>%
    rename (year = "Year")

head(weather_a)
# Out:
#   year Month    affected_area weather_event
# 1 2011 December Tasman        Heavy Rain, Flood
# 2 2011 December Nelson        Heavy Rain, Flood
# 3 2011 November West Coast    Flood, Winds
# 4 2011 November North Island  Flood, Winds
# 5 2011 August   New Zealand   Snowfall
# 6 2011 July     New Zealand   Snowfall
#   Description
# 1 There was very heavy rain in Tasman-Nelson which resulted in flooding and numerous slips in the region.
# 2 There was very heavy rain in Tasman-Nelson which resulted in flooding and numerous slips in the region.
# 3 Heavy rain brought flooding to the West Coast. There were also very high winds in Wellington and the Wairarapa.
# 4 Heavy rain brought flooding to the West Coast. There were also very high winds in Wellington and the Wairarapa.
# 5 Widespread snow in both islands caused much disruption: many roads were closed, schools were closed, CBD work was suspended in Christchurch, and power was cut to thousands of homes.
# 6 Widespread snow in both islands caused much disruption, with many roads  closed, many flights to South Island airports cancelled.

# %%
#Group weather dataframe by year and collect all events in particular year in a new column 
weather_by_year <- weather_a %>%
    group_by(year) %>%
    summarise(weather_event = paste(weather_event, collapse = ","))

weather_by_year
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   year
# 1 2011
# 2 2012
# 3 2013
# 4 2014
# 5 2015
# 6 2016
# 7 2017
#   weather_event
# 1 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 2 Tornado,Storm,Weather Bomb
# 3 Storm,Storm,Storm,Storm,Storm
# 4 Storm,Storm,Storm,Storm,Storm
# 5 Storm,Storm,Storm,Flood,Tornado,Flood
# 6 Cold Snap,Storm
# 7 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood

# %%
# Double values seen above in weather_event column 
# remove duplicated values in weather_event column
#weather_by_year <- weather_by_year %>%
    # remove spacing after commas
    #separate_rows(weather_event, sep = ", ") %>%
    #separate_rows(weather_event, sep = ",") %>%
    #group_by(year) %>%
    #summarise(weather_event = paste(unique(weather_event), collapse = ","))

#weather_by_year

# %%
# Add total weather event column for each year 
weather_by_year  <- weather_by_year %>% 
  select(year, weather_event) %>% 
  mutate(n_event = str_count(weather_event, pattern =(",") ) + 1)

weather_by_year
# Out:
#   year
# 1 2011
# 2 2012
# 3 2013
# 4 2014
# 5 2015
# 6 2016
# 7 2017
#   weather_event
# 1 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 2 Tornado,Storm,Weather Bomb
# 3 Storm,Storm,Storm,Storm,Storm
# 4 Storm,Storm,Storm,Storm,Storm
# 5 Storm,Storm,Storm,Flood,Tornado,Flood
# 6 Cold Snap,Storm
# 7 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
#   n_event
# 1 19
# 2  3
# 3  5
# 4  5
# 5  6
# 6  2
# 7  7

# %%
#group Acc claims Month df by Year , then apply sum aggregation on claims column to give year-wise total claims (sum total of all the months claims of year) made. Could use 
month <- month %>%
    group_by(year)%>%
    summarise(new_claims_total = sum(New_claims))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
month
# Out:
#   year new_claims_total
# 1 2011 32299
# 2 2012 31681
# 3 2013 32445
# 4 2014 32498
# 5 2015 36145
# 6 2016 37878
# 7 2017 38596

# %%
# Joining month df to weather dataframe 
weather_months_joined <- merge(x = month, y = weather_by_year, by = "year", all = TRUE)%>%
    arrange(desc(new_claims_total))

weather_months_joined
# Out:
#   year new_claims_total
# 1 2017 38596
# 2 2016 37878
# 3 2015 36145
# 4 2014 32498
# 5 2013 32445
# 6 2011 32299
# 7 2012 31681
#   weather_event
# 1 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 2 Cold Snap,Storm
# 3 Storm,Storm,Storm,Flood,Tornado,Flood
# 4 Storm,Storm,Storm,Storm,Storm
# 5 Storm,Storm,Storm,Storm,Storm
# 6 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 7 Tornado,Storm,Weather Bomb
#   n_event
# 1  7
# 2  2
# 3  6
# 4  5
# 5  5
# 6 19
# 7  3

# %%
#weather_months_joined %>% 
    #transform(year = as.numeric(year))

# %%
sapply(weather_months_joined, class)
# Out:
#             year new_claims_total    weather_event          n_event
#        "numeric"        "numeric"      "character"        "numeric"

# %%
weather_months_plot <- weather_months_joined%>%
    ggplot(aes(x = year, y = new_claims_total, fill = n_event)) +
    geom_col()+
    labs(x="Year", y="New Claims", title = "New ACC Motor Claims vs Year with Number of Weather events per year")+
    guides(fill=guide_legend(title="No. Weather Events"))+
    scale_fill_continuous(high = "#132B43", low = "#56B1F7")

weather_months_plot
# this shows that from 2011 to 2017 , the number of new acc claims increased,
# Out:
# plot without title

# %% [markdown]
# ## Research Question 2 - Age and Weather events - are older people more affected by weather events ?

# %%
# See age dataframe
age %>% 
    glimpse()
# Out:
# Rows: 56
# Columns: 4
# $ age           <chr> "00-19", "00-19", "00-19", "00-19", "00-19", "00-19", "…
# $ year          <dbl> 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2011, 2012, 2…
# $ active_claims <dbl> 9303, 8485, 8574, 7916, 7755, 8165, 8291, 11318, 11126,…
# $ New_claims    <dbl> 6465, 5863, 5932, 5780, 6341, 6671, 6706, 7562, 7438, 7…

# %%
# Remove column active claims
age_newclaims_df <- age %>%
    select(age, year, New_claims)
glimpse(age_newclaims_df)
# Out:
# Rows: 56
# Columns: 3
# $ age        <chr> "00-19", "00-19", "00-19", "00-19", "00-19", "00-19", "00-…
# $ year       <dbl> 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2011, 2012, 2013…
# $ New_claims <dbl> 6465, 5863, 5932, 5780, 6341, 6671, 6706, 7562, 7438, 7528…

# %%
#Check weather_by_year df 
weather_by_year
# Out:
#   year
# 1 2011
# 2 2012
# 3 2013
# 4 2014
# 5 2015
# 6 2016
# 7 2017
#   weather_event
# 1 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 2 Tornado,Storm,Weather Bomb
# 3 Storm,Storm,Storm,Storm,Storm
# 4 Storm,Storm,Storm,Storm,Storm
# 5 Storm,Storm,Storm,Flood,Tornado,Flood
# 6 Cold Snap,Storm
# 7 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
#   n_event
# 1 19
# 2  3
# 3  5
# 4  5
# 5  6
# 6  2
# 7  7

# %%
# Joining age_newclaims_df and weather_by_year dataframes by year 
weather_age_joined <- merge(x = age_newclaims_df, y = weather_by_year, by = "year", all = TRUE) %>%
    arrange(age)

weather_age_joined
# Out:
#    year age   New_claims
# 1  2011 00-19 6465
# 2  2012 00-19 5863
# 3  2013 00-19 5932
# 4  2014 00-19 5780
# 5  2015 00-19 6341
# 6  2016 00-19 6671
# 7  2017 00-19 6706
# 8  2011 20-29 7562
# 9  2012 20-29 7438
# 10 2013 20-29 7528
# 11 2014 20-29 7802
# 12 2015 20-29 8889
# 13 2016 20-29 9418
# 14 2017 20-29 9600
# 15 2011 30-39 4650
# 16 2012 30-39 4594
# 17 2013 30-39 4706
# 18 2014 30-39 4719
# 19 2015 30-39 5279
# 20 2016 30-39 5644
# 21 2017 30-39 5835
# 22 2011 40-49 5170
# 23 2012 40-49 5108
# 24 2013 40-49 5104
# 25 2014 40-49 4958
# 26 2015 40-49 5425
# 27 2016 40-49 5487
# 28 2017 40-49 5462
# 29 2011 50-59 4034
# 30 2012 50-59 4094
# 31 2013 50-59 4305
# 32 2014 50-59 4454
# 33 2015 50-59 4915
# 34 2016 50-59 4960
# 35 2017 50-59 5100
# 36 2011 60-69 2379
# 37 2012 60-69 2452
# 38 2013 60-69 2612
# 39 2014 60-69 2673
# 40 2015 60-69 2919
# 41 2016 60-69 3115
# 42 2017 60-69 3259
# 43 2011 70-79 1259
# 44 2012 70-79 1364
# 45 2013 70-79 1426
# 46 2014 70-79 1351
# 47 2015 70-79 1525
# 48 2016 70-79 1666
# 49 2017 70-79 1781
# 50 2011 80+    780
# 51 2012 80+    768
# 52 2013 80+    832
# 53 2014 80+    761
# 54 2015 80+    852
# 55 2016 80+    917
# 56 2017 80+    853
#    weather_event
# 1  Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 2  Tornado,Storm,Weather Bomb
# 3  Storm,Storm,Storm,Storm,Storm
# 4  Storm,Storm,Storm,Storm,Storm
# 5  Storm,Storm,Storm,Flood,Tornado,Flood
# 6  Cold Snap,Storm
# 7  Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 8  Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 9  Tornado,Storm,Weather Bomb
# 10 Storm,Storm,Storm,Storm,Storm
# 11 Storm,Storm,Storm,Storm,Storm
# 12 Storm,Storm,Storm,Flood,Tornado,Flood
# 13 Cold Snap,Storm
# 14 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 15 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 16 Tornado,Storm,Weather Bomb
# 17 Storm,Storm,Storm,Storm,Storm
# 18 Storm,Storm,Storm,Storm,Storm
# 19 Storm,Storm,Storm,Flood,Tornado,Flood
# 20 Cold Snap,Storm
# 21 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 22 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 23 Tornado,Storm,Weather Bomb
# 24 Storm,Storm,Storm,Storm,Storm
# 25 Storm,Storm,Storm,Storm,Storm
# 26 Storm,Storm,Storm,Flood,Tornado,Flood
# 27 Cold Snap,Storm
# 28 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 29 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 30 Tornado,Storm,Weather Bomb
# 31 Storm,Storm,Storm,Storm,Storm
# 32 Storm,Storm,Storm,Storm,Storm
# 33 Storm,Storm,Storm,Flood,Tornado,Flood
# 34 Cold Snap,Storm
# 35 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 36 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 37 Tornado,Storm,Weather Bomb
# 38 Storm,Storm,Storm,Storm,Storm
# 39 Storm,Storm,Storm,Storm,Storm
# 40 Storm,Storm,Storm,Flood,Tornado,Flood
# 41 Cold Snap,Storm
# 42 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 43 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 44 Tornado,Storm,Weather Bomb
# 45 Storm,Storm,Storm,Storm,Storm
# 46 Storm,Storm,Storm,Storm,Storm
# 47 Storm,Storm,Storm,Flood,Tornado,Flood
# 48 Cold Snap,Storm
# 49 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 50 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 51 Tornado,Storm,Weather Bomb
# 52 Storm,Storm,Storm,Storm,Storm
# 53 Storm,Storm,Storm,Storm,Storm
# 54 Storm,Storm,Storm,Flood,Tornado,Flood
# 55 Cold Snap,Storm
# 56 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
#    n_event
# 1  19
# 2   3
# 3   5
# 4   5
# 5   6
# 6   2
# 7   7
# 8  19
# 9   3
# 10  5
# 11  5
# 12  6
# 13  2
# 14  7
# 15 19
# 16  3
# 17  5
# 18  5
# 19  6
# 20  2
# 21  7
# 22 19
# 23  3
# 24  5
# 25  5
# 26  6
# 27  2
# 28  7
# 29 19
# 30  3
# 31  5
# 32  5
# 33  6
# 34  2
# 35  7
# 36 19
# 37  3
# 38  5
# 39  5
# 40  6
# 41  2
# 42  7
# 43 19
# 44  3
# 45  5
# 46  5
# 47  6
# 48  2
# 49  7
# 50 19
# 51  3
# 52  5
# 53  5
# 54  6
# 55  2
# 56  7

# %%
# Plot new_claims by year for each age range and colour by number of weather events for particular years. 
weather_age_plot <- weather_age_joined %>%
  ggplot(aes(year, New_claims, group = age, fill = n_event)) +
    geom_col() +
    facet_wrap(~ age)+
    labs(x="Year", y="New Claims", title = "New ACC Motor Claims vs Year by Age and Number of Weather events per year")+
    guides(fill=guide_legend(title="No. Weather Events"))+
    scale_fill_continuous(high = "#132B43", low = "#56B1F7")

weather_age_plot
# Out:
# plot without title

# %%
# Save the plots 
ggsave(
  "weather-ageplot.png",
  plot = weather_age_plot,
  scale = 1,
  width = 8,
  height = 5,
  dpi = 300)

# %%
# Save the plots 
ggsave(
  "weather-months-plot.png",
  plot = weather_months_plot,
  scale = 1,
  width =8,
  height = 5,
  dpi = 300)

# %% [markdown]
# ## Research Question 3 - Acc Claim Road factor and Weather events - what are the most vulnerable mode of transport.

# %%
# See road dataframe
road %>% 
    glimpse()
# Out:
# Rows: 70
# Columns: 4
# $ road_factor   <chr> "ATV", "ATV", "ATV", "ATV", "ATV", "ATV", "ATV", "Cycli…
# $ year          <dbl> 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2011, 2012, 2…
# $ active_claims <dbl> 20, 24, 42, 47, 49, 61, 52, 2470, 2501, 2508, 2318, 228…
# $ New_claims    <dbl> 10, 18, 43, 38, 50, 61, 45, 1708, 1747, 1680, 1581, 163…

# %%
# Remove active_claims variable 
road_newclaims_df <- road %>%
    select(road_factor, year, New_claims)
glimpse(road_newclaims_df)
# Out:
# Rows: 70
# Columns: 3
# $ road_factor <chr> "ATV", "ATV", "ATV", "ATV", "ATV", "ATV", "ATV", "Cycling…
# $ year        <dbl> 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2011, 2012, 201…
# $ New_claims  <dbl> 10, 18, 43, 38, 50, 61, 45, 1708, 1747, 1680, 1581, 1632,…

# %%
weather_road_joined <- merge(x = road_newclaims_df, y = weather_by_year, by = "year", all = TRUE) %>%
    arrange(road_factor)

weather_road_joined
# Out:
#    year road_factor                    New_claims
# 1  2011 ATV                               10
# 2  2012 ATV                               18
# 3  2013 ATV                               43
# 4  2014 ATV                               38
# 5  2015 ATV                               50
# 6  2016 ATV                               61
# 7  2017 ATV                               45
# 8  2011 Cycling                         1708
# 9  2012 Cycling                         1747
# 10 2013 Cycling                         1680
# 11 2014 Cycling                         1581
# 12 2015 Cycling                         1632
# 13 2016 Cycling                         1391
# 14 2017 Cycling                         1461
# 15 2011 Driving/Passenger - Bus          574
# 16 2012 Driving/Passenger - Bus          587
# 17 2013 Driving/Passenger - Bus          556
# 18 2014 Driving/Passenger - Bus          549
# 19 2015 Driving/Passenger - Bus          668
# 20 2016 Driving/Passenger - Bus          788
# 21 2017 Driving/Passenger - Bus          587
# 22 2011 Driving/Passenger - Car        22939
# 23 2012 Driving/Passenger - Car        22412
# 24 2013 Driving/Passenger - Car        23057
# 25 2014 Driving/Passenger - Car        23234
# 26 2015 Driving/Passenger - Car        26274
# 27 2016 Driving/Passenger - Car        26552
# 28 2017 Driving/Passenger - Car        26712
# 29 2011 Driving/Passenger - Motorcycle  3644
# 30 2012 Driving/Passenger - Motorcycle  3524
# ⋮  ⋮    ⋮                              ⋮
# 41 2016 Driving/Passenger - Truck       689
# 42 2017 Driving/Passenger - Truck       613
# 43 2011 Driving/Passenger-Other Veh     618
# 44 2012 Driving/Passenger-Other Veh     731
# 45 2013 Driving/Passenger-Other Veh     866
# 46 2014 Driving/Passenger-Other Veh     819
# 47 2015 Driving/Passenger-Other Veh    1021
# 48 2016 Driving/Passenger-Other Veh    1949
# 49 2017 Driving/Passenger-Other Veh    2581
# 50 2011 Not Obtainable                   22
# 51 2012 Not Obtainable                   28
# 52 2013 Not Obtainable                   22
# 53 2014 Not Obtainable                   20
# 54 2015 Not Obtainable                   26
# 55 2016 Not Obtainable                  108
# 56 2017 Not Obtainable                  198
# 57 2011 Other                           150
# 58 2012 Other                           177
# 59 2013 Other                           205
# 60 2014 Other                           194
# 61 2015 Other                           181
# 62 2016 Other                           266
# 63 2017 Other                           210
# 64 2011 Pedestrian                     2153
# 65 2012 Pedestrian                     1963
# 66 2013 Pedestrian                     1822
# 67 2014 Pedestrian                     1813
# 68 2015 Pedestrian                     1879
# 69 2016 Pedestrian                     2017
# 70 2017 Pedestrian                     1984
#    weather_event
# 1  Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 2  Tornado,Storm,Weather Bomb
# 3  Storm,Storm,Storm,Storm,Storm
# 4  Storm,Storm,Storm,Storm,Storm
# 5  Storm,Storm,Storm,Flood,Tornado,Flood
# 6  Cold Snap,Storm
# 7  Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 8  Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 9  Tornado,Storm,Weather Bomb
# 10 Storm,Storm,Storm,Storm,Storm
# 11 Storm,Storm,Storm,Storm,Storm
# 12 Storm,Storm,Storm,Flood,Tornado,Flood
# 13 Cold Snap,Storm
# 14 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 15 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 16 Tornado,Storm,Weather Bomb
# 17 Storm,Storm,Storm,Storm,Storm
# 18 Storm,Storm,Storm,Storm,Storm
# 19 Storm,Storm,Storm,Flood,Tornado,Flood
# 20 Cold Snap,Storm
# 21 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 22 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 23 Tornado,Storm,Weather Bomb
# 24 Storm,Storm,Storm,Storm,Storm
# 25 Storm,Storm,Storm,Storm,Storm
# 26 Storm,Storm,Storm,Flood,Tornado,Flood
# 27 Cold Snap,Storm
# 28 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 29 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 30 Tornado,Storm,Weather Bomb
# ⋮  ⋮
# 41 Cold Snap,Storm
# 42 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 43 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 44 Tornado,Storm,Weather Bomb
# 45 Storm,Storm,Storm,Storm,Storm
# 46 Storm,Storm,Storm,Storm,Storm
# 47 Storm,Storm,Storm,Flood,Tornado,Flood
# 48 Cold Snap,Storm
# 49 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 50 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 51 Tornado,Storm,Weather Bomb
# 52 Storm,Storm,Storm,Storm,Storm
# 53 Storm,Storm,Storm,Storm,Storm
# 54 Storm,Storm,Storm,Flood,Tornado,Flood
# 55 Cold Snap,Storm
# 56 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 57 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 58 Tornado,Storm,Weather Bomb
# 59 Storm,Storm,Storm,Storm,Storm
# 60 Storm,Storm,Storm,Storm,Storm
# 61 Storm,Storm,Storm,Flood,Tornado,Flood
# 62 Cold Snap,Storm
# 63 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 64 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 65 Tornado,Storm,Weather Bomb
# 66 Storm,Storm,Storm,Storm,Storm
# 67 Storm,Storm,Storm,Storm,Storm
# 68 Storm,Storm,Storm,Flood,Tornado,Flood
# 69 Cold Snap,Storm
# 70 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
#    n_event
# 1  19
# 2   3
# 3   5
# 4   5
# 5   6
# 6   2
# 7   7
# 8  19
# 9   3
# 10  5
# 11  5
# 12  6
# 13  2
# 14  7
# 15 19
# 16  3
# 17  5
# 18  5
# 19  6
# 20  2
# 21  7
# 22 19
# 23  3
# 24  5
# 25  5
# 26  6
# 27  2
# 28  7
# 29 19
# 30  3
# ⋮  ⋮
# 41  2
# 42  7
# 43 19
# 44  3
# 45  5
# 46  5
# 47  6
# 48  2
# 49  7
# 50 19
# 51  3
# 52  5
# 53  5
# 54  6
# 55  2
# 56  7
# 57 19
# 58  3
# 59  5
# 60  5
# 61  6
# 62  2
# 63  7
# 64 19
# 65  3
# 66  5
# 67  5
# 68  6
# 69  2
# 70  7

# %%
#labels <- c("Driving/Passenger - Bus" = "Bus", "Driving/Passenger - Car" = "Men")
#labeller=labeller(road_factor = labels)
options(repr.plot.width=12, repr.plot.height=8)
weather_road_plot <- weather_road_joined %>%
  ggplot(aes(year, New_claims, group = road_factor, fill = n_event)) +
    geom_col() +
    facet_wrap(~ road_factor)+
    labs(x="Year", y="New Claims", title = "New ACC Motor Claims vs Year by Road Factor and Number of Weather events per year" )+
    guides(fill=guide_legend(title="No. Weather Events"))+
    scale_fill_continuous(high = "#132B43", low = "#56B1F7")

weather_road_plot
# Out:
# plot without title

# %%
# Save the plot 
ggsave(
  "weather_road_plot.png",
  plot = weather_road_plot,
  scale = 1,
  width = 12,
  height = 8,
  dpi = 300)

# %% [markdown]
# ## Research Question 4 - Acc Claim Ethnicity and Weather events - is there a relationship ?

# %%
# Remove active_claims variable 
ethinicty_newclaims_df <- ethnicity %>%
    select(ethnicity, year, New_claims)
glimpse(road_newclaims_df)
# Out:
# Rows: 70
# Columns: 3
# $ road_factor <chr> "ATV", "ATV", "ATV", "ATV", "ATV", "ATV", "ATV", "Cycling…
# $ year        <dbl> 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2011, 2012, 201…
# $ New_claims  <dbl> 10, 18, 43, 38, 50, 61, 45, 1708, 1747, 1680, 1581, 1632,…

# %%
weather_ethnicity_joined <- merge(x = ethinicty_newclaims_df, y = weather_by_year, by = "year", all = TRUE) %>%
    arrange(ethnicity)

weather_ethnicity_joined
# Out:
#    year ethnicity                     New_claims
# 1  2011 Asian                          2784
# 2  2012 Asian                          2917
# 3  2013 Asian                          2982
# 4  2014 Asian                          3191
# 5  2015 Asian                          3874
# 6  2016 Asian                          4042
# 7  2017 Asian                          4401
# 8  2011 European                      21170
# 9  2012 European                      20661
# 10 2013 European                      21079
# 11 2014 European                      20784
# 12 2015 European                      22567
# 13 2016 European                      23416
# 14 2017 European                      23420
# 15 2011 Maori                          4450
# 16 2012 Maori                          4311
# 17 2013 Maori                          4347
# 18 2014 Maori                          4564
# 19 2015 Maori                          5399
# 20 2016 Maori                          5842
# 21 2017 Maori                          6015
# 22 2011 Other Ethnicities /Not stated  2320
# 23 2012 Other Ethnicities /Not stated  2271
# 24 2013 Other Ethnicities /Not stated  2322
# 25 2014 Other Ethnicities /Not stated  2206
# 26 2015 Other Ethnicities /Not stated  2256
# 27 2016 Other Ethnicities /Not stated  2368
# 28 2017 Other Ethnicities /Not stated  2596
# 29 2011 Pacific Peoples                1575
# 30 2012 Pacific Peoples                1521
# 31 2013 Pacific Peoples                1715
# 32 2014 Pacific Peoples                1753
# 33 2015 Pacific Peoples                2049
# 34 2016 Pacific Peoples                2210
# 35 2017 Pacific Peoples                2164
#    weather_event
# 1  Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 2  Tornado,Storm,Weather Bomb
# 3  Storm,Storm,Storm,Storm,Storm
# 4  Storm,Storm,Storm,Storm,Storm
# 5  Storm,Storm,Storm,Flood,Tornado,Flood
# 6  Cold Snap,Storm
# 7  Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 8  Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 9  Tornado,Storm,Weather Bomb
# 10 Storm,Storm,Storm,Storm,Storm
# 11 Storm,Storm,Storm,Storm,Storm
# 12 Storm,Storm,Storm,Flood,Tornado,Flood
# 13 Cold Snap,Storm
# 14 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 15 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 16 Tornado,Storm,Weather Bomb
# 17 Storm,Storm,Storm,Storm,Storm
# 18 Storm,Storm,Storm,Storm,Storm
# 19 Storm,Storm,Storm,Flood,Tornado,Flood
# 20 Cold Snap,Storm
# 21 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 22 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 23 Tornado,Storm,Weather Bomb
# 24 Storm,Storm,Storm,Storm,Storm
# 25 Storm,Storm,Storm,Storm,Storm
# 26 Storm,Storm,Storm,Flood,Tornado,Flood
# 27 Cold Snap,Storm
# 28 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
# 29 Heavy Rain, Flood,Heavy Rain, Flood,Flood, Winds,Flood, Winds,Snowfall,Snowfall,Tornado,Heavy Rain, Winds,Heavy Rain, Winds,Tornado,Flood,Storm,Flood
# 30 Tornado,Storm,Weather Bomb
# 31 Storm,Storm,Storm,Storm,Storm
# 32 Storm,Storm,Storm,Storm,Storm
# 33 Storm,Storm,Storm,Flood,Tornado,Flood
# 34 Cold Snap,Storm
# 35 Flood,Storm,Storm, Cyclone,Cyclone,Heavy Rain, Flood
#    n_event
# 1  19
# 2   3
# 3   5
# 4   5
# 5   6
# 6   2
# 7   7
# 8  19
# 9   3
# 10  5
# 11  5
# 12  6
# 13  2
# 14  7
# 15 19
# 16  3
# 17  5
# 18  5
# 19  6
# 20  2
# 21  7
# 22 19
# 23  3
# 24  5
# 25  5
# 26  6
# 27  2
# 28  7
# 29 19
# 30  3
# 31  5
# 32  5
# 33  6
# 34  2
# 35  7

# %%
#labels <- c("Driving/Passenger - Bus" = "Bus", "Driving/Passenger - Car" = "Men")
#labeller=labeller(road_factor = labels)
options(repr.plot.width=12, repr.plot.height=8)
weather_ethnicity_plot <- weather_ethnicity_joined %>%
  ggplot(aes(year, New_claims, group = ethnicity, fill = n_event)) +
    geom_col() +
    facet_wrap(~ ethnicity)+
    labs(x="Year", y="New Claims", title = "New ACC Motor Claims vs Year by Ethnicity and Number of Weather events per year" )+
    guides(fill=guide_legend(title="No. Weather Events"))+
    scale_fill_continuous(high = "#132B43", low = "#56B1F7")

weather_ethnicity_plot
# Out:
# plot without title

# %%
# Save the plot 
ggsave(
  "weather_ethnicity_plot.png",
  plot = weather_ethnicity_plot ,
  scale = 1,
  width = 12,
  height = 8,
  dpi = 300)
